# %%
# importing matplotlib
import matplotlib.pyplot as plt
  
# making a simple plot
a = ['Ccng1','S100a11','Anxa2','Myc','Gpc3','P4ha2','Spp1','Hmmr']
b = [1.409, 1.179, 73.734, 10.533, 2.095, 2.807, 9.370, 11.057]
  
# Plot scatter here
plt.bar(a, b)
  
c = [0.714,0.700,33.733,4.227,1.048,1.746,2.409,5.533]
  
plt.errorbar(a, b, yerr=c, fmt="o", color='red',elinewidth=1.5)
plt.title('Marker genes for HCC')
  
plt.show()

# %%
# importing matplotlib
import matplotlib.pyplot as plt
  
# making a simple plot
a = ['Akr1b10','Dusp8','Col1a1','Thy1']
b = [4.275,1.836,0.087,6.084]
  
# Plot scatter here
plt.bar(a, b)
  
c = [2.876,0.895,0.046,4.502]
  
plt.errorbar(a, b, yerr=c, fmt="o", color='orange',elinewidth=1.5)
plt.title('Marker genes for NAFLD')
  
plt.show()

# %%
# importing matplotlib
import matplotlib.pyplot as plt
  
# making a simple plot
a = ['Ddit3','Fos','Ets2']
b = [2.970,15.345,2.478]
  
# Plot scatter here
plt.bar(a, b)
  
c = [0.807,5.051,1.861]
  
plt.errorbar(a, b, yerr=c, fmt="o", color='red',elinewidth=1.5)
plt.title('Marker genes for ER Stress')
  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from array import array
from numpy import int64

#value, value, standard deviation, standard deviation 
df = pd.DataFrame([[1,2.970,0,0.807], [1,15.345,0,5.051],[1,2.478,0,1.861]], columns = ['Wild', 'KO', 'std1', 'std2'], index=['Ddit3', 'Fos','Ets2'])


figsize=(10, 100)

# convert the std columns to an array
yerr = df[['std1', 'std2']].to_numpy().T



df[['Wild', 'KO']].plot(kind='bar', yerr=yerr, alpha=0.6, error_kw=dict(ecolor='k'))
plt.title('Marker genes for ER Stress')
resolution_value = 1200
plt.savefig("ER_stress.png", format="png", dpi=resolution_value)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

XX = pd.Series([4.275,80,0.87,6.084],index=['Akr1b10','Dusp8','Col1a1','Thy1'])
fig, (ax1,ax2) = plt.subplots(2,1,sharex=True,
                         figsize=(5,6))
ax1.spines['bottom'].set_visible(False)
ax1.tick_params(axis='x',which='both',bottom=False)
ax2.spines['top'].set_visible(False)

bs = 10
ts = 70

ax2.set_ylim(0,bs)
ax1.set_ylim(ts,100)
ax1.set_yticks(np.arange(70,100,10))

bars1 = ax1.bar(XX.index, XX.values)
bars2 = ax2.bar(XX.index, XX.values)

for tick in ax2.get_xticklabels():
    tick.set_rotation(0)
d = .015  
kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
ax1.plot((-d, +d), (-d, +d), **kwargs)      
ax1.plot((1 - d, 1 + d), (-d, +d), **kwargs)
kwargs.update(transform=ax2.transAxes)  
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

for b1, b2 in zip(bars1, bars2):
    posx = b2.get_x() + b2.get_width()/2.
    if b2.get_height() > bs:
        ax2.plot((posx-3*d, posx+3*d), (1 - d, 1 + d), color='k', clip_on=False,
                 transform=ax2.get_xaxis_transform())
    if b1.get_height() > ts:
        ax1.plot((posx-3*d, posx+3*d), (- d, + d), color='k', clip_on=False,
                 transform=ax1.get_xaxis_transform())
plt.errorbar(a, b, yerr=c, fmt="o", color='red',elinewidth=1.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 40>()
#      37     if b1.get_height() > ts:
#      38         ax1.plot((posx-3*d, posx+3*d), (- d, + d), color='k', clip_on=False,
#      39                  transform=ax1.get_xaxis_transform())
# ---> 40 plt.errorbar(a, b, yerr=c, fmt="o", color='red',elinewidth=1.5)
#      41 plt.show()
#
# NameError: name 'a' is not defined

# %%
# Data
aluminum = np.array([6.4e-5 , 3.01e-5 , 2.36e-5, 3.0e-5, 7.0e-5, 4.5e-5, 3.8e-5,
                     4.2e-5, 2.62e-5, 3.6e-5])
copper = np.array([4.5e-5 , 1.97e-5 , 1.6e-5, 1.97e-5, 4.0e-5, 2.4e-5, 1.9e-5, 
                   2.41e-5 , 1.85e-5, 3.3e-5 ])
steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
                  1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
aluminum_mean = np.mean(aluminum)
copper_mean = np.mean(copper)
steel_mean = np.mean(steel)


# Calculate the standard deviation
aluminum_std = np.std(aluminum)
copper_std = np.std(copper)
steel_std = np.std(steel)


# Define labels, positions, bar heights and error bar heights
labels = ['Aluminum', 'Copper', 'Steel']
x_pos = np.arange(len(labels))
CTEs = [aluminum_mean, copper_mean, steel_mean]
error = [aluminum_std, copper_std, steel_std]

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)
ax.set_ylabel('Coefficient of Thermal Expansion')
ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
